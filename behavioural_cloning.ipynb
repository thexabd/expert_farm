# %%
# !pip install git+https://github.com/farm-gym/farm-gym
print("Successfully installed")

# %%
# Initialise the environment and add wrappers

from farmgym_games.game_builder.utils_sb3 import farmgym_to_gym_observations_flattened, wrapper
from farmgym_games.game_catalogue.farm0.farm import env as Farm0
from stable_baselines3.common.monitor import Monitor

env = Farm0()
orignal_obs, _  = env.reset()
print(f"Original observation : \n{orignal_obs}\n")

# Wrap to change observation and action spaces and the step function
env.farmgym_to_gym_observations = farmgym_to_gym_observations_flattened
env = wrapper(env)
obs, _ = env.reset()
print(f"Wrapped observation : \n{obs}\n")
# Out:
# Original observation :
# [{'Free': {'Field-0': {'Weather-0': {'day#int365': 1}}}}, {'Free': {'Field-0': {'Weather-0': {'air_temperature': {'max#°C': [3.8], 'mean#°C': [1.1], 'min#°C': [-1.9]}}}}}, {'Free': {'Field-0': {'Weather-0': {'consecutive_dry#day': [1]}}}}, {'Free': {'Field-0': {'Soil-0': {'available_Water#L': {'[(0, 0)]': [125.0]}}}}}, {'Free': {'Field-0': {'Soil-0': {'microlife_health_index#%': {'[(0, 0)]': [75.0]}}}}}, {'Free': {'Field-0': {'Plant-0': {'stage': {'[(0, 0)]': 1}}}}}, {'Free': {'Field-0': {'Plant-0': {'population#nb': {'[(0, 0)]': [1.0]}}}}}, {'Free': {'Field-0': {'Plant-0': {'size#cm': {'[(0, 0)]': [0]}}}}}, {'Free': {'Field-0': {'Plant-0': {'fruits_per_plant#nb': {'[(0, 0)]': [0]}}}}}, {'Free': {'Field-0': {'Plant-0': {'fruit_weight#g': {'[(0, 0)]': [0]}}}}}, {'Free': {'Field-0': {'Pollinators-0': {'occurrence#bin': {'[(0, 0)]': 1}}}}}]
#
# Wrapped observation :
# [1, 3.8, 1.1, -1.9, 1, 125.0, 75.0, 1, 1.0, 0, 0, 0, 0]

# %%
# Initialise the expert agent

from stable_baselines3 import PPO

expert = PPO.load("Expert_Agent_1m")

# %%
# Evaluate the expert agent

from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(expert, env, n_eval_episodes=100)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# C:\Users\abdul\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = 96.34551623334526 +/- 16.014804626530733

# %%
import numpy as np
import gym

# Function to generate offline data

def generate_offline_data(interactions):
    num_interactions = interactions

    if isinstance(env.action_space, gym.spaces.Box):
        expert_observations = np.empty((num_interactions,) + env.observation_space.shape)
        expert_actions = np.empty((num_interactions,) + (env.action_space.shape[0],))

    else:
        expert_observations = np.empty((num_interactions,) + env.observation_space.shape)
        expert_actions = np.empty((num_interactions,) + env.action_space.shape)

    obs, _ = env.reset()

    for i in range(num_interactions):
        action, _ = expert.predict(obs)
        expert_observations[i] = obs
        expert_actions[i] = action
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        if done:
            obs, _ = env.reset()

    np.savez_compressed(
        "expert_data_{}".format(interactions),
        expert_actions=expert_actions,
        expert_observations=expert_observations,
    )

    return expert_observations, expert_actions

# %%
# Expert dataset

from torch.utils.data.dataset import Dataset, random_split

class ExpertDataSet(Dataset):
    def __init__(self, expert_observations, expert_actions):
        self.observations = expert_observations
        self.actions = expert_actions

    def __getitem__(self, index):
        return (self.observations[index], self.actions[index])

    def __len__(self):
        return len(self.observations)

# %% [markdown]
# 100 Interactions

# %%
expert_observations, expert_actions = generate_offline_data(100)

# %%
expert_dataset = ExpertDataSet(expert_observations, expert_actions)

train_size = int(0.8 * len(expert_dataset))

test_size = len(expert_dataset) - train_size

train_expert_dataset, test_expert_dataset = random_split(
    expert_dataset, [train_size, test_size]
)

print("test_expert_dataset: ", len(test_expert_dataset))
print("train_expert_dataset: ", len(train_expert_dataset))
# Out:
# test_expert_dataset:  20
# train_expert_dataset:  80

# %%
import torch as th
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

def pretrain_agent(student, batch_size=64, epochs=20, scheduler_gamma=0.7, learning_rate=0.001, log_interval=100, no_cuda=True, seed=1, test_batch_size=64):
    
    use_cuda = not no_cuda and th.cuda.is_available()
    th.manual_seed(seed)
    device = th.device("cuda" if use_cuda else "cpu")
    kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

    if isinstance(env.action_space, gym.spaces.Box):
        criterion = nn.MSELoss()
    else:
        criterion = nn.CrossEntropyLoss()

    # Extract initial policy
    model = student.policy.to(device)

    def train(model, device, train_loader, optimizer):
        model.train()

        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()

            if isinstance(env.action_space, gym.spaces.Box):
                # A2C/PPO policy outputs actions, values, log_prob
                # SAC/TD3 policy outputs actions only
                if isinstance(student, (PPO)):
                    action, _, _ = model(data)
                else:
                    # SAC/TD3:
                    action = model(data)
                action_prediction = action.double()
            else:
                # Retrieve the logits for A2C/PPO when using discrete actions
                dist = model.get_distribution(data)
                action_prediction = dist.distribution.logits
                target = target.long()
                print(type(dist))
                print(type(action_prediction))

            loss = criterion(action_prediction, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0:
                print(
                    "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                        epoch,
                        batch_idx * len(data),
                        len(train_loader.dataset),
                        100.0 * batch_idx / len(train_loader),
                        loss.item(),
                    )
                )

    def test(model, device, test_loader):
        model.eval()
        test_loss = 0
        with th.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)

                if isinstance(env.action_space, gym.spaces.Box):
                    # A2C/PPO policy outputs actions, values, log_prob
                    # SAC/TD3 policy outputs actions only
                    if isinstance(student, (PPO)):
                        action, _, _ = model(data)
                    else:
                        # SAC/TD3:
                        action = model(data)
                    action_prediction = action.double()
                else:
                    # Retrieve the logits for A2C/PPO when using discrete actions
                    dist = model.get_distribution(data)
                    action_prediction = dist.distribution.logits
                    target = target.long()

                test_loss = criterion(action_prediction, target)
        test_loss /= len(test_loader.dataset)
        print(f"Test set: Average loss: {test_loss:.4f}")

    # Here, we use PyTorch `DataLoader` to our load previously created `ExpertDataset` for training
    # and testing
    train_loader = th.utils.data.DataLoader(
        dataset=train_expert_dataset, batch_size=batch_size, shuffle=True, **kwargs
    )
    test_loader = th.utils.data.DataLoader(
        dataset=test_expert_dataset,
        batch_size=test_batch_size,
        shuffle=True,
        **kwargs,
    )

    # Define an Optimizer and a learning rate schedule.
    optimizer = optim.Adadelta(model.parameters(), lr=learning_rate)
    scheduler = StepLR(optimizer, step_size=1, gamma=scheduler_gamma)

    # Now we are finally ready to train the policy model.
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, optimizer)
        test(model, device, test_loader)
        scheduler.step()

    # Implant the trained policy network back into the RL student agent
    student.policy = model

# %%
# Create agent

ppo_student_100 = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0001, n_epochs=15, tensorboard_log='pre_training')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Pretrain on 100 experiences

pretrain_agent(ppo_student_100)
ppo_student_100.save("PPO_student_100")
# Out:
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [0/80 (0%)]	Loss: 2.077088
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1037
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 2 [0/80 (0%)]	Loss: 2.076560
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1037
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 3 [0/80 (0%)]	Loss: 2.076569
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1037
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 4 [0/80 (0%)]	Loss: 2.076356
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1037
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 5 [0/80 (0%)]	Loss: 2.076334
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1037
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 6 [0/80 (0%)]	Loss: 2.076184
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 7 [0/80 (0%)]	Loss: 2.075706
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 8 [0/80 (0%)]	Loss: 2.075701
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 9 [0/80 (0%)]	Loss: 2.075833
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 10 [0/80 (0%)]	Loss: 2.075855
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 11 [0/80 (0%)]	Loss: 2.075846
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 12 [0/80 (0%)]	Loss: 2.075488
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 13 [0/80 (0%)]	Loss: 2.075691
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 14 [0/80 (0%)]	Loss: 2.075742
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 15 [0/80 (0%)]	Loss: 2.075776
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 16 [0/80 (0%)]	Loss: 2.076203
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 17 [0/80 (0%)]	Loss: 2.075632
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 18 [0/80 (0%)]	Loss: 2.075940
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 19 [0/80 (0%)]	Loss: 2.075587
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [0/80 (0%)]	Loss: 2.075545
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.1036

# %%
# Evaluate

mean_reward, std_reward = evaluate_policy(ppo_student_100, env, n_eval_episodes=100)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# Mean reward = 12.395387148986337 +/- 27.463741587716346

# %% [markdown]
# 1000 Interactions

# %%
expert_observations, expert_actions = generate_offline_data(1000)

expert_dataset = ExpertDataSet(expert_observations, expert_actions)

train_size = int(0.8 * len(expert_dataset))

test_size = len(expert_dataset) - train_size

train_expert_dataset, test_expert_dataset = random_split(
    expert_dataset, [train_size, test_size]
)

print("test_expert_dataset: ", len(test_expert_dataset))
print("train_expert_dataset: ", len(train_expert_dataset))
# Out:
# test_expert_dataset:  200
# train_expert_dataset:  800

# %%
import torch as th
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

def pretrain_agent(student, batch_size=64, epochs=20, scheduler_gamma=0.7, learning_rate=0.001, log_interval=100, no_cuda=True, seed=1, test_batch_size=64):
    
    use_cuda = not no_cuda and th.cuda.is_available()
    th.manual_seed(seed)
    device = th.device("cuda" if use_cuda else "cpu")
    kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

    if isinstance(env.action_space, gym.spaces.Box):
        criterion = nn.MSELoss()
    else:
        criterion = nn.CrossEntropyLoss()

    # Extract initial policy
    model = student.policy.to(device)

    def train(model, device, train_loader, optimizer):
        model.train()

        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()

            if isinstance(env.action_space, gym.spaces.Box):
                # A2C/PPO policy outputs actions, values, log_prob
                # SAC/TD3 policy outputs actions only
                if isinstance(student, (PPO)):
                    action, _, _ = model(data)
                else:
                    # SAC/TD3:
                    action = model(data)
                action_prediction = action.double()
            else:
                # Retrieve the logits for A2C/PPO when using discrete actions
                dist = model.get_distribution(data)
                action_prediction = dist.distribution.logits
                target = target.long()
                print(type(dist))
                print(type(action_prediction))

            loss = criterion(action_prediction, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0:
                print(
                    "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                        epoch,
                        batch_idx * len(data),
                        len(train_loader.dataset),
                        100.0 * batch_idx / len(train_loader),
                        loss.item(),
                    )
                )

    def test(model, device, test_loader):
        model.eval()
        test_loss = 0
        with th.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)

                if isinstance(env.action_space, gym.spaces.Box):
                    # A2C/PPO policy outputs actions, values, log_prob
                    # SAC/TD3 policy outputs actions only
                    if isinstance(student, (PPO)):
                        action, _, _ = model(data)
                    else:
                        # SAC/TD3:
                        action = model(data)
                    action_prediction = action.double()
                else:
                    # Retrieve the logits for A2C/PPO when using discrete actions
                    dist = model.get_distribution(data)
                    action_prediction = dist.distribution.logits
                    target = target.long()

                test_loss = criterion(action_prediction, target)
        test_loss /= len(test_loader.dataset)
        print(f"Test set: Average loss: {test_loss:.4f}")

    # Here, we use PyTorch `DataLoader` to our load previously created `ExpertDataset` for training
    # and testing
    train_loader = th.utils.data.DataLoader(
        dataset=train_expert_dataset, batch_size=batch_size, shuffle=True, **kwargs
    )
    test_loader = th.utils.data.DataLoader(
        dataset=test_expert_dataset,
        batch_size=test_batch_size,
        shuffle=True,
        **kwargs,
    )

    # Define an Optimizer and a learning rate schedule.
    optimizer = optim.Adadelta(model.parameters(), lr=learning_rate)
    scheduler = StepLR(optimizer, step_size=1, gamma=scheduler_gamma)

    # Now we are finally ready to train the policy model.
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, optimizer)
        test(model, device, test_loader)
        scheduler.step()

    # Implant the trained policy network back into the RL student agent
    student.policy = model

# %%
# Create agent

ppo_student_1000 = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0001, n_epochs=15, tensorboard_log='pre_training')

# Pretrain on 1000 experiences

pretrain_agent(ppo_student_1000)
ppo_student_1000.save("PPO_student_1000")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [0/800 (0%)]	Loss: 2.080756
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 2 [0/800 (0%)]	Loss: 2.077733
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 3 [0/800 (0%)]	Loss: 2.076557
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 4 [0/800 (0%)]	Loss: 2.075875
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 5 [0/800 (0%)]	Loss: 2.074991
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 6 [0/800 (0%)]	Loss: 2.073694
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 7 [0/800 (0%)]	Loss: 2.073310
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 8 [0/800 (0%)]	Loss: 2.074338
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 9 [0/800 (0%)]	Loss: 2.073083
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 10 [0/800 (0%)]	Loss: 2.072553
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 11 [0/800 (0%)]	Loss: 2.072111
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 12 [0/800 (0%)]	Loss: 2.072244
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0103
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 13 [0/800 (0%)]	Loss: 2.073200
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 14 [0/800 (0%)]	Loss: 2.073255
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 15 [0/800 (0%)]	Loss: 2.074085
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 16 [0/800 (0%)]	Loss: 2.073959
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 17 [0/800 (0%)]	Loss: 2.073135
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 18 [0/800 (0%)]	Loss: 2.072062
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 19 [0/800 (0%)]	Loss: 2.073205
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [0/800 (0%)]	Loss: 2.073045
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0104

# %%
# Evaluate

mean_reward, std_reward = evaluate_policy(ppo_student_1000, env, n_eval_episodes=100)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# Mean reward = 88.96232194670826 +/- 13.234582627883219

# %% [markdown]
# 10,000 Interactions

# %%
expert_observations, expert_actions = generate_offline_data(10000)

expert_dataset = ExpertDataSet(expert_observations, expert_actions)

train_size = int(0.8 * len(expert_dataset))

test_size = len(expert_dataset) - train_size

train_expert_dataset, test_expert_dataset = random_split(
    expert_dataset, [train_size, test_size]
)

print("test_expert_dataset: ", len(test_expert_dataset))
print("train_expert_dataset: ", len(train_expert_dataset))
# Out:
# test_expert_dataset:  2000
# train_expert_dataset:  8000

# %%
# Create agent

ppo_student_10000 = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0001, n_epochs=15, tensorboard_log='pre_training')

# Pretrain on 10000 experiences

pretrain_agent(ppo_student_10000)
ppo_student_10000.save("PPO_student_10000")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [0/8000 (0%)]	Loss: 2.080899
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [6400/8000 (80%)]	Loss: 2.061666
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0010
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 2 [0/8000 (0%)]	Loss: 2.054015
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 2 [6400/8000 (80%)]	Loss: 2.046011
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0010
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 3 [0/8000 (0%)]	Loss: 2.038455
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 3 [6400/8000 (80%)]	Loss: 2.029301
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0010
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 4 [0/8000 (0%)]	Loss: 2.025555
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 4 [6400/8000 (80%)]	Loss: 2.009191
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# ...
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 19 [6400/8000 (80%)]	Loss: 1.976903
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0010
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [0/8000 (0%)]	Loss: 1.979869
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [6400/8000 (80%)]	Loss: 1.980576
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0010

# %%
# Evaluate

mean_reward, std_reward = evaluate_policy(ppo_student_10000, env, n_eval_episodes=100)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# C:\Users\abdul\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = 99.92296840608935 +/- 13.870551115389814

# %% [markdown]
# 100,000 Interactions

# %%
expert_observations, expert_actions = generate_offline_data(100000)

expert_dataset = ExpertDataSet(expert_observations, expert_actions)

train_size = int(0.8 * len(expert_dataset))

test_size = len(expert_dataset) - train_size

train_expert_dataset, test_expert_dataset = random_split(
    expert_dataset, [train_size, test_size]
)

print("test_expert_dataset: ", len(test_expert_dataset))
print("train_expert_dataset: ", len(train_expert_dataset))
# Out:
# test_expert_dataset:  20000
# train_expert_dataset:  80000

# %%
# Create agent

ppo_student_100000 = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0001, n_epochs=15, tensorboard_log='pre_training')

# Pretrain on 10000 experiences

pretrain_agent(ppo_student_100000)
ppo_student_100000.save("PPO_student_100000")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [0/80000 (0%)]	Loss: 2.078000
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [6400/80000 (8%)]	Loss: 2.062625
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [12800/80000 (16%)]	Loss: 2.043105
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [19200/80000 (24%)]	Loss: 2.023065
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 1 [25600/80000 (32%)]	Loss: 2.000220
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# ...
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [70400/80000 (88%)]	Loss: 1.317137
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Train Epoch: 20 [76800/80000 (96%)]	Loss: 1.273897
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# <class 'stable_baselines3.common.distributions.CategoricalDistribution'>
# <class 'torch.Tensor'>
# Test set: Average loss: 0.0001

# %%
# Evaluate

mean_reward, std_reward = evaluate_policy(ppo_student_100000, env, n_eval_episodes=100)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# Mean reward = 94.32071288459585 +/- 14.994806901650959

# %% [markdown]
# Fine-tuning with RL

# %%
timesteps = 200000

# %%
ppo_student_100.learn(total_timesteps=timesteps)
# Out:
# Logging to pre_training\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.2     |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 452      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.4        |
# |    ep_rew_mean          | 21.8        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011033402 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.16        |
# |    n_updates            | 337         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 31.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.7        |
# |    ep_rew_mean          | 31.7        |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005080904 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 266         |
# |    n_updates            | 352         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | 32.8        |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008218354 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.9        |
# |    n_updates            | 367         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 61.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005732101 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 256         |
# |    n_updates            | 382         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 330         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.3         |
# |    ep_rew_mean          | 33.1         |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 6            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0050717564 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 105          |
# |    n_updates            | 397          |
# |    policy_gradient_loss | -0.00673     |
# |    value_loss           | 453          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.2        |
# |    ep_rew_mean          | 22.4        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006941492 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 66.8        |
# |    n_updates            | 412         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.1        |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 8           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006277191 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.8        |
# |    n_updates            | 427         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 9           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009833069 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 70.2        |
# |    n_updates            | 442         |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 493         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 10          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010110551 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.1        |
# |    n_updates            | 457         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.8        |
# |    ep_rew_mean          | 46.5        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 11          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008289762 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.5        |
# |    n_updates            | 472         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 60.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.7        |
# |    ep_rew_mean          | 67.2        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 12          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004516096 |
# |    clip_fraction        | 0.0099      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35          |
# |    n_updates            | 487         |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 225         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.4        |
# |    ep_rew_mean          | 83.4        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 13          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011276022 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 524         |
# |    n_updates            | 502         |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 14          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004808544 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.47e+03    |
# |    n_updates            | 517         |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 113       |
# |    ep_rew_mean          | 123       |
# | time/                   |           |
# |    fps                  | 341       |
# |    iterations           | 15        |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0096467 |
# |    clip_fraction        | 0.0392    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.43     |
# |    explained_variance   | 0.251     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 511       |
# |    n_updates            | 532       |
# |    policy_gradient_loss | -0.00742  |
# |    value_loss           | 1.1e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 16          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005331872 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 102         |
# |    n_updates            | 547         |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 1.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 17          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008125009 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 149         |
# |    n_updates            | 562         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 535         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 18           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0026896377 |
# |    clip_fraction        | 0.00817      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 93           |
# |    n_updates            | 577          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 19          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003317839 |
# |    clip_fraction        | 0.00326     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 592         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 896         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 136          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 20           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0071588093 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 104          |
# |    n_updates            | 607          |
# |    policy_gradient_loss | -0.008       |
# |    value_loss           | 797          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 21           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0013760863 |
# |    clip_fraction        | 0.0029       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.08e+03     |
# |    n_updates            | 622          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 1.34e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 145        |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 339        |
# |    iterations           | 22         |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00403558 |
# |    clip_fraction        | 0.0222     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 390        |
# |    n_updates            | 637        |
# |    policy_gradient_loss | -0.00628   |
# |    value_loss           | 1.03e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | 182          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 23           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0037600386 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 758          |
# |    n_updates            | 652          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 3.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | 195          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 24           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033318684 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 210          |
# |    n_updates            | 667          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 467          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 156        |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 339        |
# |    iterations           | 25         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00263598 |
# |    clip_fraction        | 0.0155     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.207      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.91e+03   |
# |    n_updates            | 682        |
# |    policy_gradient_loss | -0.00393   |
# |    value_loss           | 3.16e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 26          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006275575 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.61e+03    |
# |    n_updates            | 697         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 27           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0039075185 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.95e+03     |
# |    n_updates            | 712          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 1.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 28           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0015539113 |
# |    clip_fraction        | 0.00202      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 725          |
# |    n_updates            | 727          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 897          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 29           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0040768506 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 65.1         |
# |    n_updates            | 742          |
# |    policy_gradient_loss | -0.00542     |
# |    value_loss           | 400          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 30          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003092809 |
# |    clip_fraction        | 0.00319     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.85e+03    |
# |    n_updates            | 757         |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 31          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005022716 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 51.2        |
# |    n_updates            | 772         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 267         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 32          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003453394 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 597         |
# |    n_updates            | 787         |
# |    policy_gradient_loss | -0.00894    |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 206         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 33          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002324856 |
# |    clip_fraction        | 0.00501     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.9e+03     |
# |    n_updates            | 802         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 34           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0047160992 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.16e+03     |
# |    n_updates            | 817          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 2.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 35           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0028761537 |
# |    clip_fraction        | 0.0026       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 250          |
# |    n_updates            | 832          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 36          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008006892 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 847         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 37           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0035578904 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.442        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 318          |
# |    n_updates            | 862          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 748          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 38           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0016443814 |
# |    clip_fraction        | 0.00417      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 163          |
# |    n_updates            | 877          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 1.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 39           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0035819234 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 338          |
# |    n_updates            | 892          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 489          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 40           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0067906147 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.85e+03     |
# |    n_updates            | 907          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 1.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 41           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0035662432 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 254          |
# |    n_updates            | 922          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 1.28e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 42          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003466844 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 937         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 753         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 43          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004401841 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 539         |
# |    n_updates            | 952         |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 912         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 44          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.001576301 |
# |    clip_fraction        | 0.00498     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.83e+03    |
# |    n_updates            | 967         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 3.15e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 45           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045097955 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 692          |
# |    n_updates            | 982          |
# |    policy_gradient_loss | -0.00519     |
# |    value_loss           | 5.54e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 161        |
# |    ep_rew_mean          | 261        |
# | time/                   |            |
# |    fps                  | 337        |
# |    iterations           | 46         |
# |    time_elapsed         | 279        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00489616 |
# |    clip_fraction        | 0.025      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 748        |
# |    n_updates            | 997        |
# |    policy_gradient_loss | -0.00666   |
# |    value_loss           | 785        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 161        |
# |    ep_rew_mean          | 254        |
# | time/                   |            |
# |    fps                  | 337        |
# |    iterations           | 47         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00464183 |
# |    clip_fraction        | 0.0258     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 863        |
# |    n_updates            | 1012       |
# |    policy_gradient_loss | -0.00575   |
# |    value_loss           | 2.85e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 48           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0033824723 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 415          |
# |    n_updates            | 1027         |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 540          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 49           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0012328245 |
# |    clip_fraction        | 0.00443      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 1042         |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 2.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 50           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0025578688 |
# |    clip_fraction        | 0.00413      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 623          |
# |    n_updates            | 1057         |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 1.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 51           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0035182876 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 622          |
# |    n_updates            | 1072         |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 534          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 52           |
# |    time_elapsed         | 316          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0026991284 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 204          |
# |    n_updates            | 1087         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 781          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 53           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0014659669 |
# |    clip_fraction        | 0.00456      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 361          |
# |    n_updates            | 1102         |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 1.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 54           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0040974375 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.07e+03     |
# |    n_updates            | 1117         |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 2.61e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 55           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0018244883 |
# ...
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 81           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0019831106 |
# |    clip_fraction        | 0.00638      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 293          |
# |    n_updates            | 1522         |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 1.75e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 82          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.003384701 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 258         |
# |    n_updates            | 1537        |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 2.23e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 320           |
# | time/                   |               |
# |    fps                  | 334           |
# |    iterations           | 83            |
# |    time_elapsed         | 507           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.00094735296 |
# |    clip_fraction        | 0.00768       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | 0.496         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 103           |
# |    n_updates            | 1552          |
# |    policy_gradient_loss | -0.00196      |
# |    value_loss           | 2.09e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 314          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 84           |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0025117463 |
# |    clip_fraction        | 0.00306      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 797          |
# |    n_updates            | 1567         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 2.94e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 85           |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0024977578 |
# |    clip_fraction        | 0.00993      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 505          |
# |    n_updates            | 1582         |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 326          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 86           |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0012479868 |
# |    clip_fraction        | 0.00736      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.29e+03     |
# |    n_updates            | 1597         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 2.61e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 336         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 87          |
# |    time_elapsed         | 533         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.001965114 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.41e+03    |
# |    n_updates            | 1612        |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 3e+03       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 312          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 88           |
# |    time_elapsed         | 539          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0025688831 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 608          |
# |    n_updates            | 1627         |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 1.83e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 327         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 89          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.001521593 |
# |    clip_fraction        | 0.00908     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 534         |
# |    n_updates            | 1642        |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 826         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 308          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 90           |
# |    time_elapsed         | 551          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0011329341 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 693          |
# |    n_updates            | 1657         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 2.56e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 91          |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.002117093 |
# |    clip_fraction        | 0.00719     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 181         |
# |    n_updates            | 1672        |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 782         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 290         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 92          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.001619892 |
# |    clip_fraction        | 0.00716     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 366         |
# |    n_updates            | 1687        |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 922         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 283          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 93           |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0024498329 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 811          |
# |    n_updates            | 1702         |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 1.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 94           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0012849534 |
# |    clip_fraction        | 0.00788      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.85e+03     |
# |    n_updates            | 1717         |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 2.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 95           |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0027500195 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 406          |
# |    n_updates            | 1732         |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 842          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 96           |
# |    time_elapsed         | 588          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0023392625 |
# |    clip_fraction        | 0.0099       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 583          |
# |    n_updates            | 1747         |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 97           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0020157874 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.752        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 482          |
# |    n_updates            | 1762         |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 954          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 98          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.004075522 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 236         |
# |    n_updates            | 1777        |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 996         |
# -----------------------------------------

# %%
ppo_student_1000.learn(total_timesteps=timesteps)
# Out:
# Logging to pre_training\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.8     |
# |    ep_rew_mean     | 17.6     |
# | time/              |          |
# |    fps             | 477      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.1        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014632122 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.0387     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.58        |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 78.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.8        |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010576405 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 37.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.8       |
# |    ep_rew_mean          | 19.4       |
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 4          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00829043 |
# |    clip_fraction        | 0.024      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.645      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 17         |
# |    n_updates            | 45         |
# |    policy_gradient_loss | -0.00632   |
# |    value_loss           | 37.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | 23.3        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011446429 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.07        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 30.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008035602 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.7        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 185         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.9       |
# |    ep_rew_mean          | 27.9       |
# | time/                   |            |
# |    fps                  | 341        |
# |    iterations           | 7          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00805402 |
# |    clip_fraction        | 0.0365     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.02      |
# |    explained_variance   | 0.497      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 46.4       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00858   |
# |    value_loss           | 71.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.3         |
# |    ep_rew_mean          | 29.3         |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 8            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0056747426 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 0.0801       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 103          |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 934          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.2         |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0075388635 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2           |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 23.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 310          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.2         |
# |    ep_rew_mean          | 24.5         |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 10           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0076972353 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 318          |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.00623     |
# |    value_loss           | 682          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.9        |
# |    ep_rew_mean          | 27.7        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008926949 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00645    |
# |    value_loss           | 73.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.1       |
# |    ep_rew_mean          | 33.8       |
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 12         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01437431 |
# |    clip_fraction        | 0.053      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.404      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.9       |
# |    n_updates            | 165        |
# |    policy_gradient_loss | -0.0087    |
# |    value_loss           | 180        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.5         |
# |    ep_rew_mean          | 32.8         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 13           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0047407593 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.95e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 1.93e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 14          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008865673 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.4        |
# |    n_updates            | 195         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 154         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.9       |
# |    ep_rew_mean          | 54.6       |
# | time/                   |            |
# |    fps                  | 331        |
# |    iterations           | 15         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00368724 |
# |    clip_fraction        | 0.00999    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.22       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 872        |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00443   |
# |    value_loss           | 1.1e+03    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.3         |
# |    ep_rew_mean          | 46           |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 16           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0063816123 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0001       |
# |    loss                 | 447          |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 2.18e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.5         |
# |    ep_rew_mean          | 31.4         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 17           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0084901955 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 195          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 222          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.3        |
# |    ep_rew_mean          | 31.7        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 18          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006062451 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.29e+03    |
# |    n_updates            | 255         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 739         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.9        |
# |    ep_rew_mean          | 36.4        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 19          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008650332 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 81          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 176         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 20          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004003808 |
# |    clip_fraction        | 0.00752     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 285         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 981         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | 40.7        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 21          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004761977 |
# |    clip_fraction        | 0.00283     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 624         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.8         |
# |    ep_rew_mean          | 53.4         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 22           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0077446094 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 519          |
# |    n_updates            | 315          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 977          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.1        |
# |    ep_rew_mean          | 55.6        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 23          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007453735 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 159         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 733         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.3         |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 24           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063740285 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.54e+03     |
# |    n_updates            | 345          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 962          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.3         |
# |    ep_rew_mean          | 25.3         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 25           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0068226065 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 32.1         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 234          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.3        |
# |    ep_rew_mean          | 47.6        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 26          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004606617 |
# |    clip_fraction        | 0.00778     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 950         |
# |    n_updates            | 375         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39           |
# |    ep_rew_mean          | 46.7         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 27           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0068851714 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 122          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00735     |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 28          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004633346 |
# |    clip_fraction        | 0.00654     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 153         |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.1         |
# |    ep_rew_mean          | 21.4         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 29           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038112341 |
# |    clip_fraction        | 0.00485      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 56.6         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.1         |
# |    ep_rew_mean          | 45           |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 30           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0038562296 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 950          |
# |    n_updates            | 435          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 337          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.7        |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 31          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007387105 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 823         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | 32.2         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 32           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0052430257 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 434          |
# |    n_updates            | 465          |
# |    policy_gradient_loss | -0.00631     |
# |    value_loss           | 938          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.9         |
# |    ep_rew_mean          | 39.3         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 33           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0064576883 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 104          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 335          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 34          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006424997 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.4e+03     |
# |    n_updates            | 495         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 2.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | 53.2        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 35          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005093307 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.2        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.1        |
# |    ep_rew_mean          | 58.2        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 36          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009128778 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 525         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 2.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 37          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007471784 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 1.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.7        |
# |    ep_rew_mean          | 63.7        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 38          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002791096 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 743         |
# |    n_updates            | 555         |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 2.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | 65.1        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 39          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004615655 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 168         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 790         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.3        |
# |    ep_rew_mean          | 76          |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 40          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008169431 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 366         |
# |    n_updates            | 585         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 550         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.3         |
# |    ep_rew_mean          | 76           |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 41           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0067915744 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 383          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 1.39e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.3        |
# |    ep_rew_mean          | 79.4        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 42          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009848357 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42          |
# |    n_updates            | 615         |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 213         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.7         |
# |    ep_rew_mean          | 83.2         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 43           |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0059699416 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 1.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | 96.2        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 44          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008202488 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 645         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 93.3        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 45          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004297237 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.89e+03    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 937         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.4        |
# |    ep_rew_mean          | 91.2        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 46          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009946203 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 63.2        |
# |    n_updates            | 675         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 228         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.2         |
# |    ep_rew_mean          | 87.2         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 47           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0033898908 |
# |    clip_fraction        | 0.00169      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 115          |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 441          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 48           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0035704598 |
# |    clip_fraction        | 0.0027       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 205          |
# |    n_updates            | 705          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 2.34e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 49           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0049157813 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 497          |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 50          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007705519 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 394         |
# |    n_updates            | 735         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 51          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005940426 |
# |    clip_fraction        | 0.00905     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 450         |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 469         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 52          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008670875 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 119         |
# |    n_updates            | 765         |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 525         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 53           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0061001647 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 30.7         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00733     |
# |    value_loss           | 217          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 54          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.008525332 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.34e+03    |
# |    n_updates            | 795         |
# |    policy_gradient_loss | -0.00689    |
# |    value_loss           | 2.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 55          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.004607836 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# ...
# |    fps                  | 335          |
# |    iterations           | 81           |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0039475043 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.04e+03     |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 82           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0051308153 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 397          |
# |    n_updates            | 1215         |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 1.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 83           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0032595287 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 84.3         |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 680          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 84          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002344877 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.64e+03    |
# |    n_updates            | 1245        |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 225          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 85           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0029313546 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 115          |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 1.81e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 86           |
# |    time_elapsed         | 524          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0054962477 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 196          |
# |    n_updates            | 1275         |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 402          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 87           |
# |    time_elapsed         | 530          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0025036067 |
# |    clip_fraction        | 0.00339      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 214          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 734          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 88          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.002978458 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 314         |
# |    n_updates            | 1305        |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 580         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 89           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0037831198 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 109          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 826          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 90          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004939948 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 297         |
# |    n_updates            | 1335        |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 432         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 91           |
# |    time_elapsed         | 555          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0027706525 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.594        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 70.4         |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 284          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 183          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 92           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0033368717 |
# |    clip_fraction        | 0.00446      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 845          |
# |    n_updates            | 1365         |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 181          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 93           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0022205643 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 198          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 345          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 94           |
# |    time_elapsed         | 573          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0023549334 |
# |    clip_fraction        | 0.00736      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 538          |
# |    n_updates            | 1395         |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 548          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 95           |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0011708485 |
# |    clip_fraction        | 0.00335      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 294          |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 966          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 96           |
# |    time_elapsed         | 585          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0078076962 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 340          |
# |    n_updates            | 1425         |
# |    policy_gradient_loss | -0.0053      |
# |    value_loss           | 1.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 97           |
# |    time_elapsed         | 591          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0022557243 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.77e+03     |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 1.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 98           |
# |    time_elapsed         | 598          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0014884984 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 253          |
# |    n_updates            | 1455         |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------

# %%
ppo_student_10000.learn(total_timesteps=timesteps)
# Out:
# Logging to pre_training\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.7     |
# |    ep_rew_mean     | 15.3     |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.7        |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021251507 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.64        |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.4       |
# |    ep_rew_mean          | 13.4       |
# | time/                   |            |
# |    fps                  | 358        |
# |    iterations           | 3          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00393097 |
# |    clip_fraction        | 0.000163   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00197   |
# |    value_loss           | 44         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.7         |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0095416205 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 11.1         |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 39.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009415558 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 59.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 81.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41          |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 6           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008103997 |
# |    clip_fraction        | 0.0168      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.8        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 86.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | 24.4        |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010960946 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 8           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006698587 |
# |    clip_fraction        | 0.0097      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.9        |
# |    n_updates            | 105         |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 64.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | 30.4        |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 9           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005839834 |
# |    clip_fraction        | 0.00755     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.0618      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.59e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.7        |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 10          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005612109 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 28.6        |
# |    n_updates            | 135         |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.2        |
# |    ep_rew_mean          | 22.7        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005281791 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 64.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.2        |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 12          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008213431 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.6        |
# |    n_updates            | 165         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 13          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005130898 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 59.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.6        |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 14          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009161605 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.8        |
# |    n_updates            | 195         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 66.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.4        |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 15          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005675851 |
# |    clip_fraction        | 0.000781    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 54.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 79.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46          |
# |    ep_rew_mean          | 22.6        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 16          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006708325 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.9        |
# |    n_updates            | 225         |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 58.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.8         |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 17           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0067138677 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 29.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 52.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.7        |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 18          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006417075 |
# |    clip_fraction        | 0.0054      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.3        |
# |    n_updates            | 255         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 70.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.8        |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 19          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005858282 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.9       |
# |    ep_rew_mean          | 22.6       |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 20         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01001939 |
# |    clip_fraction        | 0.0424     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 30.4       |
# |    n_updates            | 285        |
# |    policy_gradient_loss | -0.00752   |
# |    value_loss           | 86.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.2        |
# |    ep_rew_mean          | 28.4        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 21          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005041739 |
# |    clip_fraction        | 0.00228     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 127         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 176         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.6       |
# |    ep_rew_mean          | 32.4       |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 22         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00747664 |
# |    clip_fraction        | 0.0184     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.94      |
# |    explained_variance   | 0.441      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 244        |
# |    n_updates            | 315        |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 209        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.6         |
# |    ep_rew_mean          | 35.9         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 23           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0076121623 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 266          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 316          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.2        |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 24          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005622139 |
# |    clip_fraction        | 0.00299     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 19.2        |
# |    n_updates            | 345         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 73.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.3        |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 25          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010935055 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.6        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 686         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.8         |
# |    ep_rew_mean          | 49.6         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 26           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0058001205 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 40.2         |
# |    n_updates            | 375          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 250          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.8        |
# |    ep_rew_mean          | 55.6        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 27          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005289316 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.1        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.9        |
# |    ep_rew_mean          | 62.6        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 28          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008896671 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 214         |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 475         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.6         |
# |    ep_rew_mean          | 70           |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 29           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0054187775 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 248          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 561          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.1         |
# |    ep_rew_mean          | 76           |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 30           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0087848995 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 738          |
# |    n_updates            | 435          |
# |    policy_gradient_loss | -0.00698     |
# |    value_loss           | 825          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 83.1        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 31          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008763871 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 82.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 180         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 88.5         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 32           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0042407196 |
# |    clip_fraction        | 0.00794      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 405          |
# |    n_updates            | 465          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 324          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 33          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011261851 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.9        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 89.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 34           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0050272597 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 47.1         |
# |    n_updates            | 495          |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 557          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 35          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006093081 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 557         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 36          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009112967 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 127         |
# |    n_updates            | 525         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 371         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 143        |
# |    ep_rew_mean          | 131        |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 37         |
# |    time_elapsed         | 227        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00593468 |
# |    clip_fraction        | 0.0109     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.171      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.95e+03   |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.00416   |
# |    value_loss           | 1.8e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 38          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008858911 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 103         |
# |    n_updates            | 555         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 622         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 39          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005309428 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 281         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 362         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 40          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005301259 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 59.4        |
# |    n_updates            | 585         |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 2.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 41          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003811978 |
# |    clip_fraction        | 0.00794     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 462         |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 3.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 42           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0072297724 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 615          |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 43          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.000521565 |
# |    clip_fraction        | 6.51e-05    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 426         |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 600         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 44           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0015063323 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 186          |
# |    n_updates            | 645          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 2.94e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 45           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0042426977 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 689          |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 46           |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0044008135 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 310          |
# |    n_updates            | 675          |
# |    policy_gradient_loss | -0.00463     |
# |    value_loss           | 1.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 47           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0027263735 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 140          |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 1.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 48          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004519727 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 779         |
# |    n_updates            | 705         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 758         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 226          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 49           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0042660027 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.32e+03     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 235          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 50           |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0042112954 |
# |    clip_fraction        | 0.0029       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 210          |
# |    n_updates            | 735          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 976          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 51          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.003672958 |
# |    clip_fraction        | 0.00381     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2e+03       |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 2.25e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 52           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0021583491 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 910          |
# |    n_updates            | 765          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 1.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 224          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 53           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0067083314 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 153          |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 54           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0019756716 |
# |    clip_fraction        | 0.00599      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 168          |
# |    n_updates            | 795          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 1.6e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 55           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0023002964 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# ...
# |    iterations           | 81           |
# |    time_elapsed         | 504          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0019456942 |
# |    clip_fraction        | 0.0069       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.399        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 632          |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 2.81e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 315          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 82           |
# |    time_elapsed         | 510          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0012762161 |
# |    clip_fraction        | 0.00749      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 460          |
# |    n_updates            | 1215         |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 3.96e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 326          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 83           |
# |    time_elapsed         | 516          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0026928838 |
# |    clip_fraction        | 0.0054       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 523          |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 1.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 343          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 84           |
# |    time_elapsed         | 522          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0043173856 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.56e+03     |
# |    n_updates            | 1245         |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 3.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 349         |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 85          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.004895753 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 305         |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 3.95e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | 349          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 86           |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0014043087 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.05e+03     |
# |    n_updates            | 1275         |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 2.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 335          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 87           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0010181192 |
# |    clip_fraction        | 0.00394      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 457          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 2.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 328          |
# | time/                   |              |
# |    fps                  | 329          |
# |    iterations           | 88           |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0025328638 |
# |    clip_fraction        | 0.00853      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 930          |
# |    n_updates            | 1305         |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 341          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 89           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0016661824 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.415        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 962          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 1.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | 343          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 90           |
# |    time_elapsed         | 560          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0031418228 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.71e+03     |
# |    n_updates            | 1335         |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | 351          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 91           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0026136916 |
# |    clip_fraction        | 0.00817      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.458        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.58e+03     |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 2.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 336          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 92           |
# |    time_elapsed         | 573          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0010501851 |
# |    clip_fraction        | 0.00257      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.891       |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 236          |
# |    n_updates            | 1365         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 2.35e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | 328         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 93          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.001490047 |
# |    clip_fraction        | 0.00404     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.74e+03    |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 177           |
# |    ep_rew_mean          | 316           |
# | time/                   |               |
# |    fps                  | 328           |
# |    iterations           | 94            |
# |    time_elapsed         | 585           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00075478054 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.871        |
# |    explained_variance   | 0.571         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 136           |
# |    n_updates            | 1395          |
# |    policy_gradient_loss | -0.00355      |
# |    value_loss           | 1.48e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 310          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 95           |
# |    time_elapsed         | 592          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0019102133 |
# |    clip_fraction        | 0.00397      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 666          |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 1.55e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 316          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 96           |
# |    time_elapsed         | 598          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0017603429 |
# |    clip_fraction        | 0.000358     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 173          |
# |    n_updates            | 1425         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 2.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 314          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 97           |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0032795025 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.1e+03      |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 3.77e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 318          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 98           |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0020966688 |
# |    clip_fraction        | 0.00277      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.713       |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 764          |
# |    n_updates            | 1455         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------

# %%
ppo_student_100000.learn(total_timesteps=timesteps)
# Out:
# Logging to pre_training\PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.7     |
# |    ep_rew_mean     | 56.9     |
# | time/              |          |
# |    fps             | 465      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | 67.1        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013023134 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.00299     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 252         |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 818         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.1        |
# |    ep_rew_mean          | 85.5        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005838966 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.0409      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 817         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 1.95e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.1         |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0043228297 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.0324       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 219          |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 3.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.5        |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008495604 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0401      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.38e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005927278 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0327      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 390         |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 2.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011255937 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0443      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.1        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 8           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004499198 |
# |    clip_fraction        | 0.0041      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0552      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.68e+03    |
# |    n_updates            | 105         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 2.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 9           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007769298 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0971      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 667         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 10          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005672358 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.095       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 83.3        |
# |    n_updates            | 135         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 819         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 11           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0077775735 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.06         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 233          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 2.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 12           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0036068223 |
# |    clip_fraction        | 0.00609      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0742       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 313          |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 2.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 13           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0047436845 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 734          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00537     |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 14           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0045790575 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.326        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 260          |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.00476     |
# |    value_loss           | 213          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 15          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005978486 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 106         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 221         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 16           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0040426576 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 88.2         |
# |    n_updates            | 225          |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 911          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 17          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002616053 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.0703      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.68e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 4.11e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 18           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0040708464 |
# |    clip_fraction        | 0.00999      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 255          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 1.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 19           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0033504334 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 180          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 1.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 20          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004199081 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 274         |
# |    n_updates            | 285         |
# |    policy_gradient_loss | -0.00866    |
# |    value_loss           | 809         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 168         |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 21          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003599455 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 396         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 641         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 22           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0033168686 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 113          |
# |    n_updates            | 315          |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 290          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 23           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0037823124 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 108          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 595          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 184          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 24           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0037026822 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 345          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 3.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 25           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0034129834 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 511          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 2.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 26           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0037787315 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.49e+03     |
# |    n_updates            | 375          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 3.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 27           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021452487 |
# |    clip_fraction        | 0.00729      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 752          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 835          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 28          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013804534 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 88.8        |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 300         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 29          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004914397 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 277         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 30           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0026178272 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.184        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.97e+03     |
# |    n_updates            | 435          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 2.21e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 31           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0022663232 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 285          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 3.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 32           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0036012703 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 461          |
# |    n_updates            | 465          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 1.92e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 33          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002645263 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 1.99e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 34           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0034403885 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 140          |
# |    n_updates            | 495          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 691          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 35           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0018919692 |
# |    clip_fraction        | 0.00902      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 541          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 466          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 36           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0059287515 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 221          |
# |    n_updates            | 525          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 271         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 37          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005501037 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 335         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 38          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004496865 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.37e+03    |
# |    n_updates            | 555         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 6.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 39          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002462971 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 116         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 858         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 40           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0009771697 |
# |    clip_fraction        | 0.00583      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.56e+03     |
# |    n_updates            | 585          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 2.31e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 41          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004533117 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 42           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0059272014 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 795          |
# |    n_updates            | 615          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 473          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 290         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 43          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002681355 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.44e+03    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 4.54e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 294          |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 44           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0021142785 |
# |    clip_fraction        | 0.00817      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.9e+03      |
# |    n_updates            | 645          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 3.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 45           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0029163961 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.18e+03     |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 281          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 46           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0029056582 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.55e+03     |
# |    n_updates            | 675          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 2.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 47           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0009499647 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 3.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 48           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0069313683 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.33e+03     |
# |    n_updates            | 705          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 7.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 307          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 49           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0028009498 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.68e+03     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 1.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 50           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0030490449 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.27e+03     |
# |    n_updates            | 735          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 1.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 302          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 51           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0024315312 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.845       |
# |    explained_variance   | 0.384        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 741          |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 1.28e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | 307         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 52          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.002618881 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 284         |
# |    n_updates            | 765         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 2.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 53          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.002698036 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.03e+03    |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 54          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.002423704 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 795         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 3.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 288         |
# | time/                   |             |
# |    fps                  | 330         |
# ...
# |    iterations           | 81          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.002726025 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 893         |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 1.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 348          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 82           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0030127359 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 63.5         |
# |    n_updates            | 1215         |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 1.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 357          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 83           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0016821007 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.02e+03     |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 4.3e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 346         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 84          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002764149 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.91e+03    |
# |    n_updates            | 1245        |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 2.09e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 336          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 85           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0020615314 |
# |    clip_fraction        | 0.00911      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 123          |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 1.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 342          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 86           |
# |    time_elapsed         | 537          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0046855966 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 237          |
# |    n_updates            | 1275         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 342          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 87           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0013706498 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.56         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 169          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 1.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 348          |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 88           |
# |    time_elapsed         | 549          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0010499696 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.568        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.22e+03     |
# |    n_updates            | 1305         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 1.55e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 178           |
# |    ep_rew_mean          | 358           |
# | time/                   |               |
# |    fps                  | 327           |
# |    iterations           | 89            |
# |    time_elapsed         | 555           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 0.00096925313 |
# |    clip_fraction        | 0.00713       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.764        |
# |    explained_variance   | 0.527         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.46e+03      |
# |    n_updates            | 1320          |
# |    policy_gradient_loss | -0.00227      |
# |    value_loss           | 2.55e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 346          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 90           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0013864927 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 160          |
# |    n_updates            | 1335         |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 2.83e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 339          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 91           |
# |    time_elapsed         | 568          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0024442375 |
# |    clip_fraction        | 0.00807      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 936          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 174           |
# |    ep_rew_mean          | 327           |
# | time/                   |               |
# |    fps                  | 328           |
# |    iterations           | 92            |
# |    time_elapsed         | 574           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00075454754 |
# |    clip_fraction        | 0.0043        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.684        |
# |    explained_variance   | 0.541         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.32e+03      |
# |    n_updates            | 1365          |
# |    policy_gradient_loss | -0.00205      |
# |    value_loss           | 3.07e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 329          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 93           |
# |    time_elapsed         | 580          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0013831339 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 222          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 757          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 179           |
# |    ep_rew_mean          | 339           |
# | time/                   |               |
# |    fps                  | 328           |
# |    iterations           | 94            |
# |    time_elapsed         | 586           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00065103837 |
# |    clip_fraction        | 0.00345       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.701        |
# |    explained_variance   | 0.491         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.78e+03      |
# |    n_updates            | 1395          |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 3.37e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 327         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 95          |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.002564782 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 325          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 96           |
# |    time_elapsed         | 598          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0017384981 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 531          |
# |    n_updates            | 1425         |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 961          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | 311          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 97           |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0015824429 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.556        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 198          |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 1.55e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 98          |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.001599844 |
# |    clip_fraction        | 0.00605     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 1455        |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 3.17e+03    |
# -----------------------------------------

# %%
ppo_no_pretrain = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0001, n_epochs=15, tensorboard_log='pre_training')

ppo_no_pretrain.learn(total_timesteps=timesteps)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to pre_training\PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    fps             | 451      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.8        |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011931511 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.0771     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.74        |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 25.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.1        |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012397032 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.32        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 37.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.5       |
# |    ep_rew_mean          | 16.3       |
# | time/                   |            |
# |    fps                  | 349        |
# |    iterations           | 4          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01098091 |
# |    clip_fraction        | 0.0258     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.613      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 14         |
# |    n_updates            | 45         |
# |    policy_gradient_loss | -0.00546   |
# |    value_loss           | 35.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.6        |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009797185 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00977    |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 6           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012212437 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.5        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 68.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43          |
# |    ep_rew_mean          | 23          |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006654137 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 54.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.7         |
# |    ep_rew_mean          | 23.6         |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 8            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0049885903 |
# |    clip_fraction        | 0.00462      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0.574        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 22.6         |
# |    n_updates            | 105          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 52.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.6       |
# |    ep_rew_mean          | 22.2       |
# | time/                   |            |
# |    fps                  | 334        |
# |    iterations           | 9          |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00867155 |
# |    clip_fraction        | 0.0581     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.04      |
# |    explained_variance   | 0.661      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 13.7       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 42.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29           |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 10           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0068626963 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 46.5         |
# |    n_updates            | 135          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 97           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.8        |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006845397 |
# |    clip_fraction        | 0.00697     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 566         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.6         |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 12           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0057027405 |
# |    clip_fraction        | 0.007        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 30.5         |
# |    n_updates            | 165          |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.1         |
# |    ep_rew_mean          | 15.4         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 13           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0074609015 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 21.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00697     |
# |    value_loss           | 45.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28           |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 14           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0049469084 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 193          |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.00651     |
# |    value_loss           | 229          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39           |
# |    ep_rew_mean          | 21.3         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 15           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0048613325 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 123          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 134          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 16          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010124539 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.8        |
# |    n_updates            | 225         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 36.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.3         |
# |    ep_rew_mean          | 22.2         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 17           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044596307 |
# |    clip_fraction        | 0.0026       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.94         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 79.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.7        |
# |    ep_rew_mean          | 25.8        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 18          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007954435 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.8        |
# |    n_updates            | 255         |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 45.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | 33.5        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 19          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005325538 |
# |    clip_fraction        | 0.00413     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 323         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.7        |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 20          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002923628 |
# |    clip_fraction        | 0.000163    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 580         |
# |    n_updates            | 285         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 346         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.3       |
# |    ep_rew_mean          | 21.3       |
# | time/                   |            |
# |    fps                  | 331        |
# |    iterations           | 21         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01069286 |
# |    clip_fraction        | 0.0469     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.98      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 118        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00996   |
# |    value_loss           | 145        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.8         |
# |    ep_rew_mean          | 22.2         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 22           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0076918015 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.97         |
# |    n_updates            | 315          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 42.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.3        |
# |    ep_rew_mean          | 25.9        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 23          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004675281 |
# |    clip_fraction        | 0.00983     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 130         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.5         |
# |    ep_rew_mean          | 29.2         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 24           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0064194975 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2           |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 24.2         |
# |    n_updates            | 345          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.4        |
# |    ep_rew_mean          | 35.2        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 25          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006161888 |
# |    clip_fraction        | 0.00114     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.6        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.2       |
# |    ep_rew_mean          | 33.6       |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 26         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00705712 |
# |    clip_fraction        | 0.0561     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 108        |
# |    n_updates            | 375        |
# |    policy_gradient_loss | -0.0053    |
# |    value_loss           | 297        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.3         |
# |    ep_rew_mean          | 33.4         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 27           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0065083075 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 28.5         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00695     |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.2        |
# |    ep_rew_mean          | 45.9        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 28          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008315195 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 41          |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.1        |
# |    ep_rew_mean          | 62.5        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 29          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006296939 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 471         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 570         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.8        |
# |    ep_rew_mean          | 77.9        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 30          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007910961 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 466         |
# |    n_updates            | 435         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 315         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 98.6         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 31           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0070266873 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 140          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00619     |
# |    value_loss           | 686          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 32          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005765493 |
# |    clip_fraction        | 0.00885     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 465         |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 33          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005628258 |
# |    clip_fraction        | 0.00892     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 99.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 354         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 34          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003341543 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.79e+03    |
# |    n_updates            | 495         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 1.96e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 35           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0049984492 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.61        |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 295          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 786          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 36           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039485088 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 80.3         |
# |    n_updates            | 525          |
# |    policy_gradient_loss | -0.00578     |
# |    value_loss           | 719          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 37           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0043911217 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 20           |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0055      |
# |    value_loss           | 787          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 38           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0054278476 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 555          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 39           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0030737175 |
# |    clip_fraction        | 0.00563      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 88.9         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 865          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 40          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003011797 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 160         |
# |    n_updates            | 585         |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 257         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 41           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0058452925 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 13.8         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 1.19e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 171          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 42           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0027180759 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 92.8         |
# |    n_updates            | 615          |
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 43           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0062538036 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 787          |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 1.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 191          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 44           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0032396768 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 406          |
# |    n_updates            | 645          |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 2.18e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 45          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005903526 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 825         |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 1.6e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 46           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0037917844 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.27e+03     |
# |    n_updates            | 675          |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 2.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 210          |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 47           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0043283096 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.478        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 57.4         |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 235          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 204          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 48           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0024010139 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 157          |
# |    n_updates            | 705          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 428          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 49           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013623214 |
# |    clip_fraction        | 0.00371      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.304        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 86.1         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 859          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 50           |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0015834473 |
# |    clip_fraction        | 0.0099       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 101          |
# |    n_updates            | 735          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 51           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0026708427 |
# |    clip_fraction        | 0.00573      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 52           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0056727557 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 124          |
# |    n_updates            | 765          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 860          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 53           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0033337073 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 60.4         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00747     |
# |    value_loss           | 2.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 54           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0036451279 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 109          |
# |    n_updates            | 795          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 1.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 164          |
# |    ep_rew_mean          | 226          |
# | time/                   |              |
# |    fps                  | 332          |
# ...
# |    fps                  | 320          |
# |    iterations           | 81           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0021618349 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.467        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 483          |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | 314          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 82           |
# |    time_elapsed         | 525          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0034559257 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 829          |
# |    n_updates            | 1215         |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 1.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 306          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 83           |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0030085873 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 781          |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 2.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 84          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.003564517 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 224         |
# |    n_updates            | 1245        |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 852         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 290          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 85           |
# |    time_elapsed         | 545          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0033811335 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 547          |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 942          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 283          |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 86           |
# |    time_elapsed         | 552          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0060870014 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 797          |
# |    n_updates            | 1275         |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | 287          |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 87           |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0033483845 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.642        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 590          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 755          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 88          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.001681704 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 141         |
# |    n_updates            | 1305        |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 285          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 89           |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0035737106 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 395          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.0039      |
# |    value_loss           | 1.69e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 176           |
# |    ep_rew_mean          | 297           |
# | time/                   |               |
# |    fps                  | 319           |
# |    iterations           | 90            |
# |    time_elapsed         | 577           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00089640915 |
# |    clip_fraction        | 0.00231       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | 0.611         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 765           |
# |    n_updates            | 1335          |
# |    policy_gradient_loss | -0.00167      |
# |    value_loss           | 1.12e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 297          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 91           |
# |    time_elapsed         | 583          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0015149452 |
# |    clip_fraction        | 0.0055       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 227          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 2.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 322          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 92           |
# |    time_elapsed         | 589          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0021161875 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 571          |
# |    n_updates            | 1365         |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 1.3e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 329          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 93           |
# |    time_elapsed         | 595          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0027740006 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 566          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 2.21e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 353          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 94           |
# |    time_elapsed         | 601          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0035842622 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 1395         |
# |    policy_gradient_loss | -0.00553     |
# |    value_loss           | 2.11e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | 362         |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 95          |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.003985189 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 897         |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 2.83e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | 371          |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 96           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0027304732 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 306          |
# |    n_updates            | 1425         |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 1.94e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 360          |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 97           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0035272548 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 2.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 374          |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 98           |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0037553464 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 781          |
# |    n_updates            | 1455         |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 1.34e+03     |
# ------------------------------------------

# %% [markdown]
# Evaluation of Policies with Harvest Lists

# %%
def generate_harvest_list(model):
    
    obs, _ = env.reset()

    harvest_list = []

    for _ in range (100):
        done = False
        obs, _ = env.reset()
        #print(obs)

        while not done:
            action, _ = model.predict(obs)

            #print(obs)
            #print("Action: ", action)
            
            new_obs, reward, done, _, _ = env.step(action) 
            harvest = obs[11] * obs[10]
            
            obs = new_obs
        #print("End")
        #print(obs)
        if(obs[7]==11):
            harvest_list.append(harvest)
            #print("Final yield: ", harvest)
        else:
            harvest_list.append(0)
            #print("Plant died")

    return harvest_list

# %%
import statistics

list1 = generate_harvest_list(ppo_no_pretrain)
list2 = generate_harvest_list(ppo_student_100)
list3 = generate_harvest_list(ppo_student_1000)
list4 = generate_harvest_list(ppo_student_10000)
list5 = generate_harvest_list(ppo_student_100000)

print("No pretraining: {} +/- {}".format(statistics.mean(list1), statistics.stdev(list1)))
print("100 samples pretraining: {} +/- {}".format(statistics.mean(list2), statistics.stdev(list2)))
print("1000 samples pretraining: {} +/- {}".format(statistics.mean(list3), statistics.stdev(list3)))
print("10000 samples pretraining: {} +/- {}".format(statistics.mean(list4), statistics.stdev(list4)))
print("100000 samples pretraining: {} +/- {}".format(statistics.mean(list5), statistics.stdev(list5)))
# Out:
# No pretraining: 227.81556509231575 +/- 184.19569289639566
# 100 samples pretraining: 221.44974199517824 +/- 209.2242914237117
# 1000 samples pretraining: 159.628414281688 +/- 187.6729622588512
# 10000 samples pretraining: 330.7006841052369 +/- 281.7693631958459
# 100000 samples pretraining: 279.7214095653245 +/- 242.11590489648094

# %%
list_expert = generate_harvest_list(expert)

print("Expert: {} +/- {}".format(statistics.mean(list_expert), statistics.stdev(list_expert)))
# Out:
# Expert: 307.9328381867117 +/- 218.14567190541908

# %% [markdown]
# Additional things to do:
#
# 1. Generate harvest lists before and after RL training on the pretrained models
# 2. Plot graphs on Tensorboard
